# %% [markdown]
# # Klasifikasi Citra

# %% [markdown]
# 1. Import library yang diperlukan
# 2. Load dan unzip data rps.zip dari link dataset yang diberikan
# 2. Lakukan splitting folder yang mencakup folder train, val, dan test
# 3. Melakukan Exploration Data Analyst
# 4. Lakukan Pre-processing dan Data Augmentation yang menurut kamu memberikan dataset yang lebih efisien
# 5. Implementasikan model transfer learning dengan pre-trained architectures models yang anda inginkan menggunakan Tensorflow Keras, PyTorch ataupun lainnya
# 6. Lakukan Fit Model dengan epoch yang anda tentukan
# 7. Evaluate Model dengan menampilkan Plot, Loss, Accuracy serta Classification Report
# 8. Pilih 10 gambar secara acak pada data test hasil splitting kemudian lakukan predict. Tunjukkan hasilnya kepada asisten.

# %%
pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
# Import Library
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import splitfolders

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile

local_zip = '/content/drive/MyDrive/Praktikum ML/Modul 4/Images/rps.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r') # Membaca local path
zip_ref.extractall('/tmp') # Extract .zip file
zip_ref.close()

# %%
#splittin
splitfolders.ratio('/tmp/rps', output="/tmp/modul5", seed=1337, ratio=(.7, 0.25,0.05))
# Out:
# Copying files: 2520 files [00:02, 1194.48 files/s]

# %%
# Definisikan path untuk data train dan data validation

base_dir = '/tmp/modul5'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# %%
import random
from tensorflow.keras.preprocessing.image import load_img

# Membuat plot dengan dua kolom subplot yang berada dalam satu baris
fig, ax = plt.subplots(1, 3, figsize=(15, 10)) # figsize() untuk set ukurang gambar

sample_paper = random.choice(os.listdir(train_dir + "/paper")) # library random digunakan untuk memilih data secara acak
image = load_img(train_dir + "/paper/" + sample_paper) # library load_img digunakan untuk memuat gambar dengan path yang sudah ditentukan
# set gambar untuk kolom pertama (index 0)
ax[0].imshow(image)
ax[0].set_title("paper")
ax[0].axis("Off")

sample_rock = random.choice(os.listdir(train_dir + "/rock"))
image = load_img(train_dir + "/rock/" + sample_rock)
# set gambar untuk kolom kedua (index 1)
ax[1].imshow(image)
ax[1].set_title("rock")
ax[1].axis("Off")

sample_scissors = random.choice(os.listdir(train_dir + "/scissors"))
image = load_img(train_dir + "/scissors/" + sample_scissors)
# set gambar untuk kolom kedua (index 1)
ax[2].imshow(image)
ax[2].set_title("Scissors")
ax[2].axis("Off")

plt.show()

# %%
# normalize the scale in every images using ImageDataGenerator
from keras.preprocessing.image import ImageDataGenerator

datagen     = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=30,
                    zoom_range=0.2,
                    horizontal_flip=True,
                    shear_range=0.2,               # Menambahkan shear transformation dengan kisaran 20%
                    height_shift_range=0.2,        # Menambahkan pergeseran tinggi dengan kisaran 20%
                    fill_mode='nearest')

# implement ImageDataGenerator in train data
train_gen = datagen.flow_from_directory(train_dir, #Direktori data
                                             target_size=(150, 150), #Target size image
                                             batch_size=32, #Menerapkan batch size
                                             class_mode='categorical') #Menerapkan mode kelas
# Out:
# Found 1764 images belonging to 3 classes.

# %%
val_gen = datagen.flow_from_directory(validation_dir,
                                      target_size=(150, 150),
                                      batch_size=32,
                                      class_mode='categorical')

# Menampilkan informasi banyak batch data yang digunakan dalam pelatihan dan training
print('Batches train=%d, validation=%d' % (len(train_gen), len(val_gen)))
# Out:
# Found 630 images belonging to 3 classes.
# Batches train=56, validation=20

# %%
# Fungsi ini akan memplot gambar dalam bentuk grid dengan 1 baris dan 5 kolom, di mana gambar ditempatkan di setiap kolom.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
# Visualisasi Data Train yang sudah di-augmentasi
augmented_images = [train_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %%
# Pertama, kita import dulu library yang dibutuhkan
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, Input
from tensorflow.keras.applications import EfficientNetB3

# %%
baseModel = EfficientNetB3(
                      weights="imagenet",  # Load weights pre-trained on ImageNet.
                      input_tensor=Input(shape=(150, 150, 3)), # Set Input Model dengan shape yang sesuai dengan ukuran citra
                      include_top=False,
                      )
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 2s 0us/step

# %%
# Model Summary
baseModel.summary()
# Out:
# Model: "efficientnetb3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 150, 150, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 150, 150, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 151, 151, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 75, 75, 40)           1080      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 75, 75, 40)           160       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 75, 75, 40)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 75, 75, 40)           360       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 75, 75, 40)           160       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 75, 75, 40)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 40)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 40)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 10)             410       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 40)             440       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 75, 75, 40)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 75, 75, 24)           960       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 75, 75, 24)           96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 75, 75, 24)           216       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 75, 75, 24)           96        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 75, 75, 24)           0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 24)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 75, 75, 24)           0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 75, 75, 24)           576       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 75, 75, 24)           96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 75, 75, 24)           0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 75, 75, 24)           0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 75, 75, 144)          3456      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 75, 75, 144)          576       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 75, 75, 144)          0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 77, 77, 144)          0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 38, 38, 144)          1296      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 38, 38, 144)          576       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 38, 38, 144)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 144)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 38, 38, 144)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 38, 38, 32)           4608      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 38, 38, 32)           128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 38, 38, 192)          6144      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 38, 38, 192)          768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 38, 38, 192)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 38, 38, 192)          1728      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 38, 38, 192)          768       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 38, 38, 192)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 192)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 38, 38, 192)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 38, 38, 32)           6144      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 38, 38, 32)           128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 38, 38, 32)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 38, 38, 32)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 38, 38, 192)          6144      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 38, 38, 192)          768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 38, 38, 192)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 38, 38, 192)          1728      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 38, 38, 192)          768       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 38, 38, 192)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 192)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 38, 38, 192)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 38, 38, 32)           6144      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 38, 38, 32)           128       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 38, 38, 32)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 38, 38, 32)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 38, 38, 192)          6144      ['block2c_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 38, 38, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 38, 38, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 41, 41, 192)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 19, 19, 192)          4800      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 19, 19, 192)          768       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 19, 19, 192)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 192)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 19, 19, 192)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 19, 19, 48)           9216      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 19, 19, 48)           192       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 19, 19, 288)          13824     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 19, 19, 288)          1152      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 19, 19, 288)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 19, 19, 288)          7200      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 19, 19, 288)          1152      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 19, 19, 288)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 288)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 19, 19, 288)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 19, 19, 48)           13824     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 19, 19, 48)           192       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 19, 19, 48)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 19, 19, 48)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 19, 19, 288)          13824     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 19, 19, 288)          1152      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 19, 19, 288)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, 19, 19, 288)          7200      ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, 19, 19, 288)          1152      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, 19, 19, 288)          0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 288)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, 19, 19, 288)          0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, 19, 19, 48)           13824     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, 19, 19, 48)           192       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 19, 19, 48)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 19, 19, 48)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 19, 19, 288)          13824     ['block3c_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 19, 19, 288)          1152      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 19, 19, 288)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 21, 21, 288)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 10, 10, 288)          2592      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 10, 10, 288)          1152      ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 10, 10, 288)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 288)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 10, 10, 288)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 10, 10, 96)           27648     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 10, 10, 96)           384       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 10, 10, 576)          55296     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 10, 10, 576)          2304      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 10, 10, 576)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 10, 10, 576)          5184      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 10, 10, 576)          2304      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 10, 10, 576)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 576)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 10, 10, 576)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 10, 10, 96)           55296     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 10, 10, 96)           384       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 10, 10, 96)           0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 10, 10, 96)           0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 10, 10, 576)          55296     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 10, 10, 576)          2304      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 10, 10, 576)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, 10, 10, 576)          5184      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, 10, 10, 576)          2304      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 10, 10, 576)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 576)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 10, 10, 576)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 10, 10, 96)           55296     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 10, 10, 96)           384       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 10, 10, 96)           0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 10, 10, 96)           0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 10, 10, 576)          55296     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 10, 10, 576)          2304      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 10, 10, 576)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv (DepthwiseC  (None, 10, 10, 576)          5184      ['block4d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4d_bn (BatchNormaliza  (None, 10, 10, 576)          2304      ['block4d_dwconv[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 10, 10, 576)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 576)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4d_se_reduce[0][0]']
#
# ...
#  tion)
#
#  block6e_activation (Activa  (None, 5, 5, 1392)           0         ['block6e_bn[0][0]']
#  tion)
#
#  block6e_se_squeeze (Global  (None, 1392)                 0         ['block6e_activation[0][0]']
#  AveragePooling2D)
#
#  block6e_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6e_se_squeeze[0][0]']
#  e)
#
#  block6e_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multipl  (None, 5, 5, 1392)           0         ['block6e_activation[0][0]',
#  y)                                                                  'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv  (None, 5, 5, 232)            322944    ['block6e_se_excite[0][0]']
#  2D)
#
#  block6e_project_bn (BatchN  (None, 5, 5, 232)            928       ['block6e_project_conv[0][0]']
#  ormalization)
#
#  block6e_drop (Dropout)      (None, 5, 5, 232)            0         ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)           (None, 5, 5, 232)            0         ['block6e_drop[0][0]',
#                                                                      'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2  (None, 5, 5, 1392)           322944    ['block6e_add[0][0]']
#  D)
#
#  block6f_expand_bn (BatchNo  (None, 5, 5, 1392)           5568      ['block6f_expand_conv[0][0]']
#  rmalization)
#
#  block6f_expand_activation   (None, 5, 5, 1392)           0         ['block6f_expand_bn[0][0]']
#  (Activation)
#
#  block6f_dwconv (DepthwiseC  (None, 5, 5, 1392)           34800     ['block6f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6f_bn (BatchNormaliza  (None, 5, 5, 1392)           5568      ['block6f_dwconv[0][0]']
#  tion)
#
#  block6f_activation (Activa  (None, 5, 5, 1392)           0         ['block6f_bn[0][0]']
#  tion)
#
#  block6f_se_squeeze (Global  (None, 1392)                 0         ['block6f_activation[0][0]']
#  AveragePooling2D)
#
#  block6f_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6f_se_squeeze[0][0]']
#  e)
#
#  block6f_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multipl  (None, 5, 5, 1392)           0         ['block6f_activation[0][0]',
#  y)                                                                  'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv  (None, 5, 5, 232)            322944    ['block6f_se_excite[0][0]']
#  2D)
#
#  block6f_project_bn (BatchN  (None, 5, 5, 232)            928       ['block6f_project_conv[0][0]']
#  ormalization)
#
#  block6f_drop (Dropout)      (None, 5, 5, 232)            0         ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)           (None, 5, 5, 232)            0         ['block6f_drop[0][0]',
#                                                                      'block6e_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 5, 5, 1392)           322944    ['block6f_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 5, 5, 1392)           5568      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 5, 5, 1392)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 5, 5, 1392)           12528     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 5, 5, 1392)           5568      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 5, 5, 1392)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1392)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 5, 5, 1392)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 5, 5, 384)            534528    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 5, 5, 384)            1536      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 5, 5, 2304)           884736    ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 5, 5, 2304)           9216      ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 5, 5, 2304)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 5, 5, 2304)           20736     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 5, 5, 2304)           9216      ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 5, 5, 2304)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 2304)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 2304)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 96)             221280    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 2304)           223488    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 5, 5, 2304)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 5, 5, 384)            884736    ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 5, 5, 384)            1536      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 5, 5, 384)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 5, 5, 384)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)           (None, 5, 5, 1536)           589824    ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 5, 5, 1536)           6144      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 5, 5, 1536)           0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 10783535 (41.14 MB)
# Trainable params: 10696232 (40.80 MB)
# Non-trainable params: 87303 (341.03 KB)
# __________________________________________________________________________________________________

# %%
# Freeze the baseModel karena sudah dilakukan training
baseModel.trainable = False

# %%
model = tf.keras.Sequential([
    baseModel,
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(3, activation="softmax")
])

# %%
# Model Summary yang kita buat
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb3 (Functional  (None, 5, 5, 1536)        10783535
#  )
#
#  max_pooling2d (MaxPooling2  (None, 2, 2, 1536)        0
#  D)
#
#  flatten (Flatten)           (None, 6144)              0
#
#  dense (Dense)               (None, 3)                 18435
#
# =================================================================
# Total params: 10801970 (41.21 MB)
# Trainable params: 18435 (72.01 KB)
# Non-trainable params: 10783535 (41.14 MB)
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.001),
              loss = tf.keras.losses.CategoricalCrossentropy(),
              metrics = [tf.keras.metrics.CategoricalAccuracy()])

# %%
history = model.fit(train_gen,
          validation_data=val_gen,
          steps_per_epoch=20, epochs=20)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 124s 6s/step - loss: 1.2536 - categorical_accuracy: 0.3016 - val_loss: 1.1619 - val_categorical_accuracy: 0.3333
# Epoch 2/20
# 20/20 [==============================] - 132s 7s/step - loss: 1.1398 - categorical_accuracy: 0.3250 - val_loss: 1.1130 - val_categorical_accuracy: 0.4254
# Epoch 3/20
# 20/20 [==============================] - 131s 7s/step - loss: 1.1380 - categorical_accuracy: 0.3313 - val_loss: 1.0932 - val_categorical_accuracy: 0.3333
# Epoch 4/20
# 20/20 [==============================] - 94s 5s/step - loss: 1.1372 - categorical_accuracy: 0.3072 - val_loss: 1.1373 - val_categorical_accuracy: 0.3333
# Epoch 5/20
# 20/20 [==============================] - 129s 7s/step - loss: 1.1234 - categorical_accuracy: 0.3889 - val_loss: 1.0698 - val_categorical_accuracy: 0.5063
# Epoch 6/20
# 20/20 [==============================] - 131s 7s/step - loss: 1.1013 - categorical_accuracy: 0.3812 - val_loss: 1.0680 - val_categorical_accuracy: 0.3460
# Epoch 7/20
# 20/20 [==============================] - 95s 5s/step - loss: 1.1339 - categorical_accuracy: 0.3464 - val_loss: 1.2039 - val_categorical_accuracy: 0.3333
# Epoch 8/20
# 20/20 [==============================] - 128s 7s/step - loss: 1.1631 - categorical_accuracy: 0.3644 - val_loss: 1.0808 - val_categorical_accuracy: 0.4762
# Epoch 9/20
# 20/20 [==============================] - 132s 7s/step - loss: 1.0971 - categorical_accuracy: 0.3719 - val_loss: 1.0822 - val_categorical_accuracy: 0.3508
# Epoch 10/20
# 20/20 [==============================] - 130s 7s/step - loss: 1.0958 - categorical_accuracy: 0.3703 - val_loss: 1.0916 - val_categorical_accuracy: 0.3937
# Epoch 11/20
# 20/20 [==============================] - 134s 7s/step - loss: 1.1079 - categorical_accuracy: 0.4000 - val_loss: 1.0557 - val_categorical_accuracy: 0.3556
# Epoch 12/20
# 20/20 [==============================] - 131s 7s/step - loss: 1.0984 - categorical_accuracy: 0.3891 - val_loss: 1.0539 - val_categorical_accuracy: 0.4286
# Epoch 13/20
# 20/20 [==============================] - 131s 7s/step - loss: 1.0692 - categorical_accuracy: 0.3984 - val_loss: 1.0807 - val_categorical_accuracy: 0.4794
# Epoch 14/20
# 20/20 [==============================] - 129s 7s/step - loss: 1.0592 - categorical_accuracy: 0.4363 - val_loss: 1.1145 - val_categorical_accuracy: 0.3746
# Epoch 15/20
# 20/20 [==============================] - 130s 7s/step - loss: 1.1405 - categorical_accuracy: 0.3954 - val_loss: 1.1182 - val_categorical_accuracy: 0.3333
# Epoch 16/20
# 20/20 [==============================] - 97s 5s/step - loss: 1.1440 - categorical_accuracy: 0.3391 - val_loss: 1.1256 - val_categorical_accuracy: 0.3651
# Epoch 17/20
# 20/20 [==============================] - 95s 5s/step - loss: 1.0995 - categorical_accuracy: 0.4003 - val_loss: 1.0348 - val_categorical_accuracy: 0.4937
# Epoch 18/20
# 20/20 [==============================] - 131s 7s/step - loss: 1.0633 - categorical_accuracy: 0.4234 - val_loss: 1.0677 - val_categorical_accuracy: 0.3937
# Epoch 19/20
# 20/20 [==============================] - 131s 7s/step - loss: 1.0564 - categorical_accuracy: 0.4563 - val_loss: 1.0566 - val_categorical_accuracy: 0.4968
# Epoch 20/20
# 20/20 [==============================] - 131s 7s/step - loss: 1.0410 - categorical_accuracy: 0.4484 - val_loss: 1.0857 - val_categorical_accuracy: 0.3444

# %%
# Visualization Accuracy, Val Accuracy, Loss and Val Loss
import matplotlib.pyplot as plt
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(13, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Akurasi')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Loss')
plt.show()

# %%
# Printout Accuracy and Loss
loss, accuracy = model.evaluate_generator(val_gen)
print("Validation: \nAccuracy = %f  \nLoss = %f " % (accuracy, loss))
# Out:
# <ipython-input-21-3c456f471a43>:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   loss, accuracy = model.evaluate_generator(val_gen)
# Validation:
# Accuracy = 0.346032
# Loss = 1.089249

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Memperoleh prediksi probabilitas untuk setiap sampel dalam dataset validasi
y_pred = model.predict(val_gen )

# Mengambil indeks kelas dengan probabilitas tertinggi untuk setiap sampel
y_pred_classes = np.argmax(y_pred, axis=1)

# Mengambil indeks kelas sebenarnya dari dataset validasi
true_classes = val_gen .classes

# Mendapatkan nama kelas dari indeks kelas
class_labels = list(val_gen .class_indices.keys())

# Menampilkan classification report
print(classification_report(true_classes, y_pred_classes, target_names=class_labels))
# Out:
# 20/20 [==============================] - 51s 2s/step
#               precision    recall  f1-score   support
#
#        paper       0.33      0.01      0.02       210
#         rock       0.00      0.00      0.00       210
#     scissors       0.33      0.99      0.50       210
#
#     accuracy                           0.33       630
#    macro avg       0.22      0.33      0.17       630
# weighted avg       0.22      0.33      0.17       630
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model.save('EFFICIENTNET_H5.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.models import load_model

# %%
model = load_model('EFFICIENTNET_H5.h5')

# %%
def load_and_preprocess_images(folder, label, num_images=10):
    image_paths = [os.path.join(folder, file) for file in os.listdir(folder)]
    random.shuffle(image_paths)
    images = []
    labels = []

    for i, image_path in enumerate(image_paths):
        if i >= num_images:
            break

        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB format
        image = cv2.resize(image, (150, 150))  # Resize the image to match your model input size
        image = image / 255.0  # Normalize pixel values to [0, 1]

        images.append(image)

        # Extract the label from the folder name
        labels.append(label)

    return np.array(images), labels

# %%
import cv2
num_images = 4
rock_images, rock_labels = load_and_preprocess_images('/tmp/modul5/test/rock', 'rock', num_images)
paper_images, paper_labels = load_and_preprocess_images('/tmp/modul5/test/paper', 'paper', num_images)
scissors_images, scissors_labels = load_and_preprocess_images('/tmp/modul5/test/scissors', 'scissors', num_images)

# %%
images = np.vstack((rock_images, paper_images, scissors_images))
true_labels = rock_labels + paper_labels + scissors_labels
predictions = model.predict(images)
label_mapping = {0: "paper", 1: "rock", 2: "scissor"}
predicted_labels = [label_mapping[np.argmax(prediction)] for prediction in predictions]
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
plt.figure(figsize=(15, 6))
for i in range(num_images * 3):
    plt.subplot(3, num_images, i + 1)
    plt.tight_layout()
    plt.imshow(images[i])
    plt.title(f"Predicted : {predicted_labels[i]}")
    plt.xlabel(f"True : {true_labels[i]}")
    plt.grid(visible=None)

plt.show()
